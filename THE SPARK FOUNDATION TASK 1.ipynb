# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("F:\Python programs\Data.csv")

# %%
data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Scores')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
x = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values 
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30, random_state=0)
regression = LinearRegression()
regression.fit(x_train, y_train)
line = regression.coef_*x+regression.intercept_
plt.scatter(x, y)
plt.plot(x, line)
plt.show()

# %%
print(x_test)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]
#  [3.8]
#  [1.9]
#  [7.8]]

# %%
y_pred = regression.predict(x_test)
df = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
print(df)
# Out:
#    Actual  Predicted
# 0      20  17.053665
# 1      27  33.694229
# 2      69  74.806209
# 3      30  26.842232
# 4      62  60.123359
# 5      35  39.567369
# 6      24  20.969092
# 7      86  78.721636

# %%
hours=9.25
pred1 = regression.predict([[hours]])
print("If the student studies for {} hours per day then student will score {}%".format(hours,pred1))
# Out:
# If the student studies for 9.25 hours per day then student will score [92.91505723]%

# %%
from sklearn import metrics  
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.419727808027652
